# %%
import numpy as np

w1 = 0.08
w2 = 0.2

t = np.linspace(0, 2 * np.pi, 101)
l = t * 100 / np.max(t)

y = 0.5 * (w2 - w1) * (np.cos(t) + 1) + w1

import matplotlib.pyplot as plt

plt.figure(dpi=150)
plt.plot(l,  y)
plt.plot(l, -y)
plt.grid()
plt.show()
